# %%
C = float(input("Enter temperature in celsius"))

F = (9/5)*C + 32
roundF= round(F, 2)

print("Temperatue in Fahreneheit :", roundF)
# Out:
# Enter temperature in celsius39.1
# Temperatue in Fahreneheit : 102.38
